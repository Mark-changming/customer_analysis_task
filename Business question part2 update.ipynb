# %%
import numpy as np
import pandas as pd 
import pandas_profiling
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set(style="darkgrid")
# %matplotlib inline

# %%
df_aisles = pd.read_csv("./data/aisles/aisles.csv")
df_departments = pd.read_csv("./data/departments/departments.csv")
df_order_products = pd.read_csv("./data/order_products/order_products.csv")
df_orders = pd.read_csv("./data/orders/orders.csv")
df_products = pd.read_csv("./data/products/products.csv")

# %%
df_orders
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# 2                          21.0
# 3                          29.0
# 4                          28.0
# ...                         ...
# 3421078                    29.0
# 3421079                    30.0
# 3421080                    18.0
# 3421081                     7.0
# 3421082                    30.0
#
# [3421083 rows x 6 columns]

# %%
df_order_products
# Out:
#           order_id  product_id  add_to_cart_order
# 0                2       33120                  1
# 1                2       28985                  2
# 2                2        9327                  3
# 3                2       45918                  4
# 4                2       30035                  5
# ...            ...         ...                ...
# 33819101   3421063       14233                  3
# 33819102   3421063       35548                  4
# 33819103   3421070       35951                  1
# 33819104   3421070       16953                  2
# 33819105   3421070        4724                  3
#
# [33819106 rows x 3 columns]

# %%
df1 = pd.merge(df_orders, df_order_products, on="order_id", how="inner")
df2 = pd.merge(df1, df_products, on="product_id")
df3 = pd.merge(df2, df_aisles, on="aisle_id")
df_all = pd.merge(df3, df_departments, on="department_id")
df_all
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2398795        1             2          3                  7
# 2           473747        1             3          3                 12
# 3          2254736        1             4          4                  7
# 4           431534        1             5          4                 15
# ...            ...      ...           ...        ...                ...
# 33819101   2939884   130327             3          1                 13
# 33819102   3267360   150683             1          5                 16
# 33819103    414077   159238             9          6                 12
# 33819104    813243   171675            13          2                  6
# 33819105    909758   176580             4          6                 15
#
#           days_since_prior_order  product_id  add_to_cart_order  \
# 0                            NaN         196                  1
# 1                           15.0         196                  1
# 2                           21.0         196                  1
# 3                           29.0         196                  1
# 4                           28.0         196                  1
# ...                          ...         ...                ...
# 33819101                     0.0       27414                  5
# 33819102                     NaN       27414                 13
# 33819103                     8.0       27414                  1
# 33819104                    13.0       27414                 34
# 33819105                     5.0       27414                 15
#
#                  product_name  aisle_id  department_id  \
# 0                        Soda        77              7
# 1                        Soda        77              7
# 2                        Soda        77              7
# 3                        Soda        77              7
# 4                        Soda        77              7
# ...                       ...       ...            ...
# 33819101  Organic Emmer Farro        68             10
# 33819102  Organic Emmer Farro        68             10
# 33819103  Organic Emmer Farro        68             10
# 33819104  Organic Emmer Farro        68             10
# 33819105  Organic Emmer Farro        68             10
#
#                                  aisle department
# 0                          soft drinks  beverages
# 1                          soft drinks  beverages
# 2                          soft drinks  beverages
# 3                          soft drinks  beverages
# 4                          soft drinks  beverages
# ...                                ...        ...
# 33819101  bulk grains rice dried goods       bulk
# 33819102  bulk grains rice dried goods       bulk
# 33819103  bulk grains rice dried goods       bulk
# 33819104  bulk grains rice dried goods       bulk
# 33819105  bulk grains rice dried goods       bulk
#
# [33819106 rows x 13 columns]

# %%
df_all.head(20)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
# 11   2968173       15            15          1                  9
# 12   1870022       15            17          2                 16
# 13   1911383       15            18          2                 11
# 14   2715276       15            21          1                  9
# 15    487368       15            22          1                 10
# 16   2293453       19             2          5                 14
# 17   1973799       19             5          6                 12
# 18    532817       19             7          4                 17
# 19   1573906       21            10          3                 10
#
#     days_since_prior_order  product_id  add_to_cart_order product_name  \
# 0                      NaN         196                  1         Soda
# 1                     15.0         196                  1         Soda
# 2                     21.0         196                  1         Soda
# 3                     29.0         196                  1         Soda
# 4                     28.0         196                  1         Soda
# 5                     19.0         196                  1         Soda
# 6                     20.0         196                  1         Soda
# 7                     14.0         196                  2         Soda
# 8                      0.0         196                  4         Soda
# 9                     30.0         196                  1         Soda
# 10                    14.0         196                  1         Soda
# 11                     7.0         196                  2         Soda
# 12                     8.0         196                  6         Soda
# 13                     7.0         196                  1         Soda
# 14                     7.0         196                  1         Soda
# 15                    14.0         196                  1         Soda
# 16                     6.0         196                  3         Soda
# 17                     8.0         196                 15         Soda
# 18                     6.0         196                  1         Soda
# 19                     6.0         196                  2         Soda
#
#     aisle_id  department_id        aisle department
# 0         77              7  soft drinks  beverages
# 1         77              7  soft drinks  beverages
# 2         77              7  soft drinks  beverages
# 3         77              7  soft drinks  beverages
# 4         77              7  soft drinks  beverages
# 5         77              7  soft drinks  beverages
# 6         77              7  soft drinks  beverages
# 7         77              7  soft drinks  beverages
# 8         77              7  soft drinks  beverages
# 9         77              7  soft drinks  beverages
# 10        77              7  soft drinks  beverages
# 11        77              7  soft drinks  beverages
# 12        77              7  soft drinks  beverages
# 13        77              7  soft drinks  beverages
# 14        77              7  soft drinks  beverages
# 15        77              7  soft drinks  beverages
# 16        77              7  soft drinks  beverages
# 17        77              7  soft drinks  beverages
# 18        77              7  soft drinks  beverages
# 19        77              7  soft drinks  beverages

# %% [markdown]
# ### Q1

# %%
df = df_all[["user_id", 'order_number']]

df_new = df.groupby('user_id')['order_number'].max().reset_index()

# %%
max_number = df_new.order_number
sns.distplot(max_number)
# Out:
# /Users/Mark/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='order_number', ylabel='Density'>

# %%
df_new[df_new['order_number'] < 60]
# Out:
#         user_id  order_number
# 0             1            11
# 1             2            15
# 2             3            12
# 3             4             5
# 4             5             5
# ...         ...           ...
# 206203   206204             4
# 206204   206205             4
# 206206   206207            16
# 206207   206208            49
# 206208   206209            14
#
# [199425 rows x 2 columns]

# %%
max_number = df_new[df_new['order_number'] < 60].order_number
sns.distplot(max_number)
# Out:
# <AxesSubplot:xlabel='order_number', ylabel='Density'>

# %% [markdown]
# ### Q2

# %%
df_all.department.mode()
# Out:
# 0    produce
# dtype: object

# %%
df_all.aisle.mode()
# Out:
# 0    fresh fruits
# dtype: object

# %%
"""Customers' favorite departments and Aisles is produce and fresh fruits"""
# Out:
# "Customers' favorite departments and Aisles is produce and fresh fruits"

# %% [markdown]
# ### Q3

# %%
df_all
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2398795        1             2          3                  7
# 2           473747        1             3          3                 12
# 3          2254736        1             4          4                  7
# 4           431534        1             5          4                 15
# ...            ...      ...           ...        ...                ...
# 33819101   2939884   130327             3          1                 13
# 33819102   3267360   150683             1          5                 16
# 33819103    414077   159238             9          6                 12
# 33819104    813243   171675            13          2                  6
# 33819105    909758   176580             4          6                 15
#
#           days_since_prior_order  product_id  add_to_cart_order  \
# 0                            NaN         196                  1
# 1                           15.0         196                  1
# 2                           21.0         196                  1
# 3                           29.0         196                  1
# 4                           28.0         196                  1
# ...                          ...         ...                ...
# 33819101                     0.0       27414                  5
# 33819102                     NaN       27414                 13
# 33819103                     8.0       27414                  1
# 33819104                    13.0       27414                 34
# 33819105                     5.0       27414                 15
#
#                  product_name  aisle_id  department_id  \
# 0                        Soda        77              7
# 1                        Soda        77              7
# 2                        Soda        77              7
# 3                        Soda        77              7
# 4                        Soda        77              7
# ...                       ...       ...            ...
# 33819101  Organic Emmer Farro        68             10
# 33819102  Organic Emmer Farro        68             10
# 33819103  Organic Emmer Farro        68             10
# 33819104  Organic Emmer Farro        68             10
# 33819105  Organic Emmer Farro        68             10
#
#                                  aisle department
# 0                          soft drinks  beverages
# 1                          soft drinks  beverages
# 2                          soft drinks  beverages
# 3                          soft drinks  beverages
# 4                          soft drinks  beverages
# ...                                ...        ...
# 33819101  bulk grains rice dried goods       bulk
# 33819102  bulk grains rice dried goods       bulk
# 33819103  bulk grains rice dried goods       bulk
# 33819104  bulk grains rice dried goods       bulk
# 33819105  bulk grains rice dried goods       bulk
#
# [33819106 rows x 13 columns]

# %%
df_all.groupby(['order_id', 'department'])['aisle'].nunique()
# Out:
# order_id  department
# 1         canned goods    1
#           dairy eggs      3
#           produce         2
# 2         dairy eggs      1
#           pantry          5
#                          ..
# 3421083   babies          1
#           frozen          1
#           household       1
#           produce         1
#           snacks          3
# Name: aisle, Length: 15866589, dtype: int64

# %%
df_all.groupby('department')['aisle'].max()
# Out:
# department
# alcohol                              white wines
# babies                             diapers wipes
# bakery                      tortillas flat bread
# beverages          water seltzer sparkling water
# breakfast               hot cereal pancake mixes
# bulk                bulk grains rice dried goods
# canned goods                 soup broth bouillon
# dairy eggs                                yogurt
# deli                      tofu meat alternatives
# dry goods pasta                      pasta sauce
# frozen                             ice cream ice
# household                      trash bags liners
# international                       latino foods
# meat seafood                     seafood counter
# missing                                  missing
# other                                      other
# pantry                                   spreads
# personal care               vitamins supplements
# pets                               dog food care
# produce               packaged vegetables fruits
# snacks                       trail mix snack mix
# Name: aisle, dtype: object

# %% [markdown]
# #### Q3 used answer
# #### ---------------------

# %%
labels = df_all.department.unique().tolist()
best_aisle = []
for i in labels:
    df = df_all[df_all["department"] == i][['order_number', 'aisle', 'department']]
    best_aisle.append(df.loc[df.order_number.idxmax()]['aisle'])
    
print(best_aisle)
# Out:
# ['soft drinks', 'soy lactosefree', 'popcorn jerky', 'paper goods', 'fresh fruits', 'cereal', 'spreads', 'lunch meat', 'frozen meals', 'oral hygiene', 'packaged poultry', 'asian foods', 'breakfast bakery', 'canned meat seafood', 'instant foods', 'red wines', 'dog food care', 'baby food formula', 'other', 'missing', 'bulk dried fruits vegetables']

# %%
print(labels)
# Out:
# ['beverages', 'dairy eggs', 'snacks', 'household', 'produce', 'breakfast', 'pantry', 'deli', 'frozen', 'personal care', 'meat seafood', 'international', 'bakery', 'canned goods', 'dry goods pasta', 'alcohol', 'pets', 'babies', 'other', 'missing', 'bulk']

# %%
best_selling_Aisles = pd.DataFrame({'department':labels,'best_aisle':best_aisle})
best_selling_Aisles
# Out:
#          department                    best_aisle
# 0         beverages                   soft drinks
# 1        dairy eggs               soy lactosefree
# 2            snacks                 popcorn jerky
# 3         household                   paper goods
# 4           produce                  fresh fruits
# 5         breakfast                        cereal
# 6            pantry                       spreads
# 7              deli                    lunch meat
# 8            frozen                  frozen meals
# 9     personal care                  oral hygiene
# 10     meat seafood              packaged poultry
# 11    international                   asian foods
# 12           bakery              breakfast bakery
# 13     canned goods           canned meat seafood
# 14  dry goods pasta                 instant foods
# 15          alcohol                     red wines
# 16             pets                 dog food care
# 17           babies             baby food formula
# 18            other                         other
# 19          missing                       missing
# 20             bulk  bulk dried fruits vegetables

# %% [markdown]
# ### Q4

# %% [markdown]
# #### userd answer

# %%
X = []
for i in df_all['department'].unique().tolist():
    X.append(df_all[df_all["department"] == i]['order_number'].sum())
    
print(X)
# Out:
# [48292820, 99447482, 51655845, 12151378, 176103461, 12384615, 32426214, 18066442, 36160893, 7574482, 11749748, 4620539, 21048641, 17989899, 14392589, 2423859, 1568954, 8480976, 655924, 1738204, 725731]

# %%
labels = df_all.department.unique().tolist()


plt.subplots(nrows=1, ncols=1, figsize=(10,10))
plt.pie(X, labels=labels, shadow=True, startangle=45) 
plt.axis('equal')
plt.title("The number of orders in each departments chart")
  
 
plt.show()

# %% [markdown]
# #### update answer

# %%
df_all
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2398795        1             2          3                  7
# 2           473747        1             3          3                 12
# 3          2254736        1             4          4                  7
# 4           431534        1             5          4                 15
# ...            ...      ...           ...        ...                ...
# 33819101   2939884   130327             3          1                 13
# 33819102   3267360   150683             1          5                 16
# 33819103    414077   159238             9          6                 12
# 33819104    813243   171675            13          2                  6
# 33819105    909758   176580             4          6                 15
#
#           days_since_prior_order  product_id  add_to_cart_order  \
# 0                            NaN         196                  1
# 1                           15.0         196                  1
# 2                           21.0         196                  1
# 3                           29.0         196                  1
# 4                           28.0         196                  1
# ...                          ...         ...                ...
# 33819101                     0.0       27414                  5
# 33819102                     NaN       27414                 13
# 33819103                     8.0       27414                  1
# 33819104                    13.0       27414                 34
# 33819105                     5.0       27414                 15
#
#                  product_name  aisle_id  department_id  \
# 0                        Soda        77              7
# 1                        Soda        77              7
# 2                        Soda        77              7
# 3                        Soda        77              7
# 4                        Soda        77              7
# ...                       ...       ...            ...
# 33819101  Organic Emmer Farro        68             10
# 33819102  Organic Emmer Farro        68             10
# 33819103  Organic Emmer Farro        68             10
# 33819104  Organic Emmer Farro        68             10
# 33819105  Organic Emmer Farro        68             10
#
#                                  aisle department
# 0                          soft drinks  beverages
# 1                          soft drinks  beverages
# 2                          soft drinks  beverages
# 3                          soft drinks  beverages
# 4                          soft drinks  beverages
# ...                                ...        ...
# 33819101  bulk grains rice dried goods       bulk
# 33819102  bulk grains rice dried goods       bulk
# 33819103  bulk grains rice dried goods       bulk
# 33819104  bulk grains rice dried goods       bulk
# 33819105  bulk grains rice dried goods       bulk
#
# [33819106 rows x 13 columns]

# %%
df_all.groupby('department').order_number.count()
# Out:
# department
# alcohol             159294
# babies              438743
# bakery             1225181
# beverages          2804175
# breakfast           739069
# bulk                 35932
# canned goods       1114857
# dairy eggs         5631067
# deli               1095540
# dry goods pasta     905340
# frozen             2336858
# household           774652
# international       281155
# meat seafood        739238
# missing              77396
# other                38086
# pantry             1956819
# personal care       468693
# pets                102221
# produce            9888378
# snacks             3006412
# Name: order_number, dtype: int64

# %%
X = df_all.groupby('department').order_number.count().tolist()

# %%
labels = [t for t in df_all.groupby('department').department.unique()]
labels
# Out:
# [array(['alcohol'], dtype=object),
#  array(['babies'], dtype=object),
#  array(['bakery'], dtype=object),
#  array(['beverages'], dtype=object),
#  array(['breakfast'], dtype=object),
#  array(['bulk'], dtype=object),
#  array(['canned goods'], dtype=object),
#  array(['dairy eggs'], dtype=object),
#  array(['deli'], dtype=object),
#  array(['dry goods pasta'], dtype=object),
#  array(['frozen'], dtype=object),
#  array(['household'], dtype=object),
#  array(['international'], dtype=object),
#  array(['meat seafood'], dtype=object),
#  array(['missing'], dtype=object),
#  array(['other'], dtype=object),
#  array(['pantry'], dtype=object),
#  array(['personal care'], dtype=object),
#  array(['pets'], dtype=object),
#  array(['produce'], dtype=object),
#  array(['snacks'], dtype=object)]

# %%
plt.subplots(nrows=1, ncols=1, figsize=(10,10))
plt.pie(X, labels=labels, shadow=True, startangle=45) 
plt.axis('equal')
plt.title("The number of orders in each departments chart")
  
 
plt.show()
